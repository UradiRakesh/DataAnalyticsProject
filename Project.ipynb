# %% [markdown]
# **IMPORTIG** **PACKAGES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# **DATA** **PREVIEW**

# %%
statistics = pd.read_csv("/content/AI_index_db (1).csv",encoding=('ISO.8859-1'),low_memory=False )
statistics
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 1                      China   16.51          100.00                  91.57
# 2             United Kingdom   39.65           71.43                  74.65
# 3                     Canada   31.28           77.05                  93.94
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 57                 Sri Lanka    6.27           34.64                  35.79
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 60                   Nigeria    2.74            0.00                  50.10
# 61                  Pakistan    8.00            2.43                  12.48
#
# ...

# %% [markdown]
# **COLUMN** **NAMES**

# %%
statistics.columns
# Out:
# Index(['Country', 'Talent', 'Infrastructure', 'Operating Environment',
#        'Research', 'Development', 'Government Strategy', 'Commercial',
#        'Total score', 'Region', 'Cluster', 'Income group', 'Political regime'],
#       dtype='object')

# %% [markdown]
# **EXPLORING** **DATA**

# %%
statistics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                62 non-null     object
#  1   Talent                 62 non-null     float64
#  2   Infrastructure         62 non-null     float64
#  3   Operating Environment  62 non-null     float64
#  4   Research               62 non-null     float64
#  5   Development            62 non-null     float64
#  6   Government Strategy    62 non-null     float64
#  7   Commercial             62 non-null     float64
#  8   Total score            62 non-null     float64
#  9   Region                 62 non-null     object
#  10  Cluster                62 non-null     object
#  11  Income group           62 non-null     object
#  12  Political regime       62 non-null     object
# dtypes: float64(8), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# **OBSERVING** **DATA**

# %%
statistics.describe()
# Out:
#            Talent  Infrastructure  Operating Environment    Research  \
# count   62.000000       62.000000              62.000000   62.000000
# mean    16.803065       63.503710              66.925484   16.610000
# std     15.214963       20.217525              20.000424   17.413996
# min      0.000000        0.000000               0.000000    0.000000
# 25%      7.365000       55.857500              58.107500    3.032500
# 50%     13.445000       65.230000              69.505000   12.930000
# 75%     24.567500       75.947500              80.500000   25.412500
# max    100.000000      100.000000             100.000000  100.000000
#
#        Development  Government Strategy  Commercial  Total score
# count    62.000000            62.000000   62.000000    62.000000
# mean     14.824677            57.865645    6.171935    23.914677
# std      19.419279            26.252448   14.029632    15.123586
# min       0.000000             0.000000    0.000000     0.000000
# ...

# %% [markdown]
# **MISSING** **VALUES**

# %%
statistics.isnull().sum()
# Out:
# Country                  0
# Talent                   0
# Infrastructure           0
# Operating Environment    0
# Research                 0
# Development              0
# Government Strategy      0
# Commercial               0
# Total score              0
# Region                   0
# Cluster                  0
# Income group             0
# Political regime         0
# dtype: int64

# %% [markdown]
# # **PIECHART**

# %%
PIE = px.pie(statistics.head(20),values='Infrastructure',names='Country',title='Percentage of Total Infrastructure in 20 Most  Countries',template="plotly_dark")
PIE.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **BARGRAPH**

# %%
BAR = px.bar(statistics.head(20), y='Development',x='Country',color='Region',height=400)
BAR.update_layout(title='Comparison of Development of 20 Most  Countries',xaxis_title='Country',yaxis_title='Development',template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **BUBBLE** **PLOT**

# %%
# Bubble Chart using Plotly
Bub = px.scatter(statistics.head(40), x="Total score", y="Research",size='Total score',
	               color="Region",
                 hover_name="Country", log_x=False, size_max=60)
Bub.update_layout(title='Bubble plot for Total Score vs Research of 50 most Countries ',xaxis_title='Total score',yaxis_title='Research',template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **LINE** **CHART**

# %%
LINE = px.line(statistics.head(20), y='Talent',x='Country',height=600)
LINE.update_layout(title='Countries based on Talent',xaxis_title='country',yaxis_title='Talent',template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **SCATTER** **PLOT**

# %%
SCTR = px.scatter(statistics.head(60), y='Government Strategy',x='Country',height=600)
SCTR.update_layout(title='Government Strategy V/S Country',xaxis_title='Country',yaxis_title='Government Strategy',template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #  **3D** **Scatter** **Plot**

# %%
import plotly.express as px
sctr = px.scatter_3d(statistics.head(25), x='Country',y='Research', z='Government Strategy',
              color='Region')
sctr.update_layout(title='Countries and their Government Strategies,Research in Top 25 Countries', autosize=True,
                  width=900, height=700,
                  margin=dict(l=65, r=50, b=65, t=90),
                 xaxis= dict(title= 'Country',ticklen= 100),
                 yaxis= dict(title= 'Research',ticklen= 100),
                template="plotly_dark",

                 font=dict(
        family="Times New Roman",
        size=15))
sctr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **HEAT** **GRAPH**

# %%
import plotly.express as px

CNTR=px.density_heatmap(statistics.head()[['Development','Operating Environment','Total score']].corr())
CNTR.update_layout(title='Relationship between Development,Operating Environment & Total score')
CNTR.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Bar** **Plot**

# %%
import plotly.graph_objects as px
import numpy

plot = px.Figure(data=[go.Bar(
    name='Development (TOP25)', #name of bar
    x=statistics.head(25)['Country'], #x-axis values
    y=statistics.head(25)['Development'] , #y-axis values
    marker = dict(color = 'blue',
                              line=dict(color='rgb(0,0,0)',width=1.0))#properties of bar like color,border
),
    go.Bar(
    name='Talent (TOP25)',
    x=statistics.head(25)['Country'],
    y=statistics.head(25)['Talent'],
        marker = dict(color = 'yellow',
                              line=dict(color='rgb(0,0,0)',width=1.0))
),
  go.Bar(
    name='Research (TOP25)',
    x=statistics.head(25)['Country'],
    y=statistics.head(25)['Research'],
      marker = dict(color = 'white',
                              line=dict(color='rgb(0,0,0)',width=1.0))
),
    go.Bar(
    name='Government Strategy (TOP25)',
    x=statistics.head(25)['Country'],
    y=statistics.head(25)['Government Strategy'],
    marker = dict(color = 'crimson',
                              line=dict(color='rgb(0,0,0)',width=1.0))
),
    go.Bar(
    name='Commercial (TOP25)',
    x=statistics.head(25)['Country'],
    y=statistics.head(25)['Commercial'],
    marker = dict(color = 'crimson',
                              line=dict(color='rgb(0,0,0)',width=1.0))
)
])


# Add dropdown
plot.update_layout(
    template="plotly_dark",
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label="All",
                     method="update",
                     args=[{"visible": [True, True, True, True,True]},
                           {"title": "All"}]),
                dict(label="Development (TOP25)",
                     method="update",
                     args=[{"visible": [True, False, False, False,False]},
                           {"title": "Development (TOP25)",
                            }]),
                dict(label="Talent (TOP25)",
                     method="update",
                     args=[{"visible": [False, True, False, False,False]},
                           {"title": "Talent (TOP25)",
                            }]),
                dict(label="Research (TOP25)",
                     method="update",
                     args=[{"visible": [False, False, True, False,False]},
                           {"title": "Research (TOP25)",
                            }]),
                dict(label="Government Strategy (TOP25)",
                     method="update",
                     args=[{"visible": [False, False, False, True,False]},
                           {"title": "Government Strategy (TOP25)",
                            }]),
                dict(label="Commercial (TOP25)",
                     method="update",
                     args=[{"visible": [False, False, False, False,True]},
                           {"title": "Commercial (TOP25)",
                            }]),

            ]),
        )
    ])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **WATERFALL** **CHART**

# %%
import plotly.graph_objects as go

statistics = {'Talent': [1, 2, 3, 4, 5],
               'Total Score': [10, 20, 30, 40, 50]}

water = go.Figure(go.Waterfall(x=statistics['Talent'], y=statistics['Total Score'], base=0, increasing_marker_color='green', decreasing_marker_color='red'))

water.update_layout(title='Waterfall Chart',
                  xaxis_title='Talent',
                  yaxis_title='Total Score',template="plotly_dark")
water.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **HISTOGRAM**

# %%
import plotly.express as px
HIST = px.histogram(pd.read_csv('AI_index_db (1).csv').head(10), y='Research',x='Country',height=600)
HIST.update_layout(title='Research V/S Country',xaxis_title='Country',yaxis_title='Research',template="plotly_dark")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **3D MESH Plot**

# %%
import plotly.graph_objects as go
import pandas as pd
# Load the data from a CSV file
df = pd.read_csv("/content/AI_index_db (1).csv")
# Data for the mesh plot
data = [
    go.Mesh3d(
        x=df['Talent'],
        y=df['Infrastructure'],
        z=df['Operating Environment'],
        opacity=0.5,
        color='rgba(244,22,100,0.6)'
    )
]

# Layout settings for the plot
layout = go.Layout(
    title='3D Mesh Plot of Talent, Infrastructure, and Operating Environment',
    scene=dict(
        xaxis=dict(title='Talent'),
        yaxis=dict(title='Infrastructure'),
        zaxis=dict(title='Operating Environment')
    )
)

# Create the figure
fig1 = go.Figure(data=data, layout=layout)

# Display the plot
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **DASHBOARD**

# %%
pip install dash

# %%
import dash
from dash import html   #to need to code html components
import dash_core_components as dcc
import plotly.graph_objects as go
import plotly.express as px
from dash.dependencies import Input, Output
from plotly.subplots import make_subplots


external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']



app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Country Development',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='By Rakesh', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    dcc.Graph(id='firstgraph13',figure=PIE,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),



    dcc.Graph(id='firstgraph1',figure=BAR,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph2',figure=Bub,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph3',figure=LINE,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph4',figure=SCTR,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph5',figure=sctr,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph6',figure=CNTR,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph7',figure=plot,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph9',figure=water,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph10',figure=HIST,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph12',figure=fig1,style={'width':'80%','display':'inline-block','backgroundColor': colors['background']})
 ])
@app.callback(
    Output('firstgraph1','figure'),
    [Input('dropdown_1','value')])


def update_figure(graphtype):
    global fig
    if graphtype=='CC':
        fig=go.Figure(px.bar(statistics.head(10), y='Government Strategy',x='Country',color='Talent',height=400))
        fig.update_layout(title="Comparison of Government Strategy of 20 most Countries",template="plotly_dark")
    if graphtype=='D':
        fig=go.Figure(px.bar(statistics.head(10), y='Infrastructure',x='Country',color='Talent',height=400))
        fig.update_layout(title="Comparison of Infrastructure of 10 Most  Countries",template="plotly_dark")
    if graphtype=='DC':
        fig=go.Figure(px.bar(statistics.head(10), y='Research',x='Country',color='Talent',height=400))
        fig.update_layout(title="Comparison Research of 10 Most Countries",template="plotly_dark")
    return fig


if __name__ == '__main__':
    app.run_server()
